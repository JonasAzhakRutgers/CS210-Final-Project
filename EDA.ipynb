# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('attorney_case_dataset.csv', na_values=[], keep_default_na=False)

print(df.head())
print(df.info())
print(df.describe())

print("\nMissing values:\n", df.isnull().sum())

# 1) Distribution of Case Result
sns.countplot(x='Case_Result', data=df)
plt.title("Distribution of Case Result")
plt.xlabel("Case Result")
plt.ylabel("Count")
plt.show()

# 2) Attorney Experience vs Case Result
sns.boxplot(x='Case_Result', y='Experience_Years', data=df)
plt.title("Attorney Experience vs Case Result")
plt.xlabel("Case Result")
plt.ylabel("Years of Experience")
plt.show()

# 3) Average Win/Loss Ratio by Education Level
sns.barplot(x='Education_Level', y='Win_Loss_Ratio', data=df)
plt.title("Average Win/Loss Ratio by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Avg. Win/Loss Ratio")
plt.xticks(rotation=45)
plt.show()

# 4) Weighted Score Distribution by Case Result
sns.violinplot(x='Case_Result', y='Weighted_Score', data=df)
plt.title("Weighted Score Distribution by Case Result")
plt.xlabel("Case Result")
plt.ylabel("Weighted Score")
plt.show()

# 5) Correlation Matrix of Numeric Features
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
#    Experience_Years  Win_Loss_Ratio Education_Level  Weighted_Score  \
# 0                16            0.72              JD            0.62
# 1                 0            0.49              JD            0.29
# 2                11            0.59              JD            0.50
# 3                13            0.37             LLM            0.50
# 4                 1            0.38              JD            0.27
#
#    Case_Results
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience_Years  200 non-null    int64
#  1   Win_Loss_Ratio    200 non-null    float64
#  2   Education_Level   200 non-null    object
#  3   Weighted_Score    200 non-null    float64
#  4   Case_Results      200 non-null    int64
# ...
